# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
from IPython.core.display import display, HTML 
# display(HTML(my_html)) 
import time
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.8) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "

# %%
source_code = requests.get('https://www.nba.com/stats/alltime-leaders/')

# %%
soup = BeautifulSoup(source_code.text, 'lxml')

# %%
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# <html lang="en" ng-app="stats" ng-strict-di="" stats-build-date="2021-12-22 02:51 PM" stats-version="4.47.1" xmlns:ng="http://angularjs.org">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=Edge,chrome=1" http-equiv="X-UA-Compatible"/><script type="text/javascript">(window.NREUM||(NREUM={})).init={ajax:{deny_list:["bam-cell.nr-data.net"]}};(window.NREUM||(NREUM={})).loader_config={xpid:"VQECWF5UChAHUlNTBwgBVw==",licenseKey:"09f0cb5c68",applicationID:"76210961"};window.NREUM||(NREUM={}),__nr_require=function(t,e,n){function r(n){if(!e[n]){var i=e[n]={exports:{}};t[n][0].call(i.exports,function(e){var i=t[n][1][e];return r(i||e)},i,i.exports)}return e[n].exports}if("function"==typeof __nr_require)return __nr_require;for(var i=0;i<n.length;i++)r(n[i]);return r}({1:[function(t,e,n){function r(t){try{s.console&&console.log(t)}catch(e){}}var i,o=t("ee"),a=t(28),s={};try{i=localStorage.getItem("__nr_flags").split(","),console&&"function"==typeof console.log&&(s.console=!0,i.indexOf("dev")!==-1&&(s.dev=!0),i.indexOf("nr_dev")!==-1&&(s.nrDev=!0))}catch(c){}s.nrDev&&o.on("internal-error",function(t){r(t.stack)}),s.dev&&o.on("fn-err",function(t,e,n){r(n.stack)}),s.dev&&(r("NR AGENT IN DEVELOPMENT MODE"),r("flags: "+a(s,function(t,e){return t}).join(", ")))},{}],2:[function(t,e,n){function r(t,e,n,r,s){try{p?p-=1:i(s||new UncaughtException(t,e,n),!0)}catch(f){try{o("ierr",[f,c.now(),!0])}catch(d){}}return"function"==typeof u&&u.apply(this,a(arguments))}function UncaughtException(t,e,n){this.message=t||"Uncaught error with no additional information",this.sourceURL=e,this.line=n}function i(t,e){var n=e?null:c.now();o("err",[t,n])}var o=t("handle"),a=t(29),s=t("ee"),c=t("loader"),f=t("gos"),u=window.onerror,d=!1,l="nr@seenError";if(!c.disabled){var p=0;c.features.err=!0,t(1),window.onerror=r;try{throw new Error}catch(h){"stack"in h&&(t(10),t(9),"addEventListener"in window&&t(6),c.xhrWrappable&&t(11),d=!0)}s.on("fn-start",function(t,e,n){d&&(p+=1)}),s.on("fn-err",function(t,e,n){d&&!n[l]&&(f(n,l,function(){return!0}),this.thrown=!0,i(n))}),s.on("fn-end",function(){d&&!this.thrown&&p>0&&(p-=1)}),s.on("internal-error",function(t){o("ierr",[t,c.now(),!0])})}},{}],3:[function(t,e,n){var r=t("loader");r.disabled||(r.features.ins=!0)},{}],4:[function(t,e,n){function r(){var t=new PerformanceObserver(function(t,e){var n=t.getEntries();s(v,[n])});try{t.observe({entryTypes:["resource"]})}catch(e){}}function i(t){if(s(v,[window.performance.getEntriesByType(w)]),window.performance["c"+l])try{window.performance[h](m,i,!1)}catch(t){}else try{window.performance[h]("webkit"+m,i,!1)}catch(t){}}function o(t){}if(window.performance&&window.performance.timing&&window.performance.getEntriesByType){var a=t("ee"),s=t("handle"),c=t(10),f=t(9),u=t(5),d=t(19),l="learResourceTimings",p="addEventListener",h="removeEventListener",m="resourcetimingbufferfull",v="bstResource",w="resource",g="-start",y="-end",x="fn"+g,b="fn"+y,E="bstTimer",R="pushState",S=t("loader");if(!S.disabled){S.features.stn=!0,t(8),"addEventListener"in window&&t(6);var O=NREUM.o.EV;a.on(x,function(t,e){var n=t[0];n instanceof O&&(this.bstStart=S.now())}),a.on(b,function(t,e){var n=t[0];n instanceof O&&s("bst",[n,e,this.bstStart,S.now()])}),c.on(x,function(t,e,n){this.bstStart=S.now(),this.bstType=n}),c.on(b,function(t,e){s(E,[e,this.bstStart,S.now(),this.bstType])}),f.on(x,function(){this.bstStart=S.now()}),f.on(b,function(t,e){s(E,[e,this.bstStart,S.now(),"requestAnimationFrame"])}),a.on(R+g,function(t){this.time=S.now(),this.startPath=location.pathname+location.hash}),a.on(R+y,function(t){s("bstHist",[location.pathname+location.hash,this.startPath,this.time])}),u()?(s(v,[window.performance.getEntriesByType("resource")]),r()):p in window.performance&&(window.performance["c"+l]?window.performance[p](m,i,d(!1)):window.performance[p]("webkit"+m,i,d(!1))),document[p]("scroll",o,d(!1)),document[p]("keypress",o,d(!1)),document[p]("click",o,d(!1))}}},{}],5:[function(t,e,n){e.exports=function(){return"PerformanceObserver"in window&&"function"==typeof window.PerformanceObserver}},{}],6:[function(t,e,n){function r(t){for(var e=t;e&&!e.hasOwnProperty(u);)e=Object.getPrototypeOf ...
# <title> All Time Leaders | Stats | NBA.com</title>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="The all time official leaders for the NBA." name="description"/>
# <link href="https://www.nba.com/stats/alltime-leaders/" rel="canonical"/>
# <base href="/stats/alltime-leaders/"/>
# <meta content="http://www.nba.com/stats/alltime-leaders/" property="og:url"/>
# <meta content="website" property="og:type"/>
# <meta content="NBA Stats" property="og:site_name"/>
# <meta content="All Time Leaders" property="og:title"/>
# <meta content="The all time official leaders for the NBA." property="og:description"/>
# <meta content="/stats/media/img/touch/stats-icon-152x152.png" property="og:image"/>
# <meta content="Basketball" property="og:sport"/>
# <meta content="NBA" property="og:sports_league"/>
# <meta content="no" name="msapplication-tap-highlight"/>
# <link href="/stats/manifest.json" rel="manifest"/>
# <meta content="#051c2e" name="theme-color"/>
# <meta content="yes" name="mobile-web-app-capable"/>
# <meta content="NBA Stats" name="application-name"/>
# <meta content="yes" name="apple-mobile-web-app-capable"/>
# <meta content="NBA Stats" name="apple-mobile-web-app-title"/>
# <link href="/stats/media/img/touch/stats-icon-152x152.png" rel="icon" sizes="152x152"/>
# <link href="/stats/media/img/touch/stats-icon-128x128.png" rel="apple-touch-icon"/>
# <link href="/stats/favicon.png" rel="shortcut icon"/>
# <link href="https://fonts.googleapis.com/css?family=Roboto:400,500,700|Roboto+Condensed" rel="stylesheet"/>
# <link href="/stats/styles/theme.min.css?rev=12a542e745acfa725d04357d50132c3c" rel="stylesheet" type="text/css"/>
# <script>window.nbaStatsRoute = '/stats/alltime-leaders/';</script>
# </head>
# <body>
# <!-- top-next -->
# <script>
#   function getTChannelName() {
#     var base = "stats.nba.com:";
#     var cpath = location.pathname.replace(/#/g, "").replace(/\/$/, "").replace(/\//gi, ':');
#
#     if (cpath === "" || cpath === ":") {
#       cpath = "main";
#     } else {
#       cpath = cpath.split(':')[1];
#     }
#
#     return base + cpath;
#   }
#
#   function getPageName(pkg) {
#     var base = "";
#     var cpath = "";
#
#     if (pkg === "t") {
#       base = "stats.nba.com:";
#       cpath = location.pathname.replace(/#/g, "").replace(/\/$/, "");
#
#       return base + cpath + "/stats/";
#     } else if (pkg === "n") {
#       base = "us:stats";
#       cpath = location.pathname.replace(/#/g, "").replace(/\/$/, "").replace(/\//gi, ':');
#
#       if (cpath.indexOf('scores') > -1 && cpath.indexOf('boxscores') === -1) {
#         var splitPath = cpath.split(":");
#         cpath = ":" + splitPath[1] + ":" + splitPath.slice(-3).join('');
#       }
#
#       if (cpath === "" || cpath === ":") {
#         cpath = ":main";
#       }
#
#       return base + cpath;
#     } else {
#       return null;
#     }
#   }
#
#   // hardcode the aam_uuid cookie to the data layer
#   function getUUID(cookies) {
#     if (cookies) {
#       for (var i = 0; i < cookies.split(';').length; i++) {
#         var cookie = cookies[i];
#         if (cookie.indexOf('aam_uuid') !== -1) {
#           return cookie.split('=')[1];
#         }
#       }
#     }
#
#     return '';
#   }
#
#   var tChannelName = getTChannelName();
#   var tPageName = getPageName("t");
#   var nPageName = getPageName("n");
#   var uuid = getUUID(document.cookie);
#
#   // write initial page on load object
#   window.digitalData = {
#     tPageName: tPageName,
#     nPageName: nPageName,
#     tChannel: tChannelName,
#     nChannel: tChannelName,
#     registeredUser: "",
#     page: {
#       pageInfo: {
#         uuid: uuid
#       }
#     }
#   };
# </script>
# <script async="" src="//assets.adobedtm.com/"></script>
# <div class="nba-nav-placeholder" id="nba-nav"></div> <div class="nav-container" ng-cloak="" ng-controller="StatsHeaderController" stats-fixed-nav="">
# <div class="nav-wrapper shadow-md">
# <div class="nav-inner">
# <!-- left: inner nav -->
# <div class="nav-inner__title">Stats</div>
# <div class="nav-inner__divider"></div>
# <nav class="nav-inner__menu" role="navigation">
# <div class="nav-inner__menu-item">
# <a class="nav-inner__btn" href="/stats/" ng-class="{ active: activeTab=='home' }">Home</a>
# </div>
# <div class="nav-inner__menu-item nav-inner__btn-players">
# <button aria-expanded="{{isPlayersOpen}}" aria-haspopup="true" class="nav-inner__btn" ng-class="{ active: activeTab=='players' }" ng-click="togglePlayers()">
#             Players
#             <svg class="arrow" height="7" ng-class="{ open: isPlayersOpen }" viewbox="0 0 11 7" width="11" xmlns="http://www.w3.org/2000/svg">
# <path d="M110 4L114 8 110 12" fill="none" stroke="#999" stroke-width="2" transform="rotate(90 61.25 -47.75)"></path>
# </svg>
# </button>
# </div>
# <div class="nav-inner__menu-item">
# <button aria-expanded="{{isTeamsOpen}}" aria-haspopup="true" class="nav-inner__btn nav-inner__btn-teams" ng-class="{ active: activeTab=='teams' }" ng-click="toggleTeams()">
#             Teams
#             <svg class="arrow" height="7" ng-class="{ open: isTeamsOpen }" viewbox="0 0 11 7" width="11" xmlns="http://www.w3.org/2000/svg">
# <path d="M110 4L114 8 110 12" fill="none" stroke="#999" stroke-width="2" transform="rotate(90 61.25 -47.75)"></path>
# </svg>
# </button>
# </div>
# <div class="nav-inner__menu-item">
# <button aria-expanded="{{isLeadersOpen}}" aria-haspopup="true" class="nav-inner__btn nav-inner__btn-leaders" ng-class="{ active: activeTab=='leaders' }" ng-click="toggleLeaders()">
#             Leaders
#             <svg class="arrow" height="7" ng-class="{ open: isLeadersOpen }" viewbox="0 0 11 7" width="11" xmlns="http://www.w3.org/2000/svg">
# <path d="M110 4L114 8 110 12" fill="none" stroke="#999" stroke-width="2" transform="rotate(90 61.25 -47.75)"></path>
# </svg>
# </button>
# </div>
# <div class="nav-inner__menu-item">
# <button aria-expanded="{{isStats101Open}}" aria-haspopup="true" class="nav-inner__btn nav-inner__btn-stats101" ng-click="toggleStats101()">
#             Stats 101
#             <svg class="arrow" height="7" ng-class="{ open: isStats101Open }" viewbox="0 0 11 7" width="11" xmlns="http://www.w3.org/2000/svg">
# <path d="M110 4L114 8 110 12" fill="none" stroke="#999" stroke-width="2" transform="rotate(90 61.25 -47.75)"></path>
# </svg>
# </button>
# </div>
# <div class="nav-inner__menu-item">
# <button aria-expanded="{{isToolsOpen}}" aria-haspopup="true" class="nav-inner__btn nav-inner__btn-tools" ng-click="toggleTools()">
#             Tools
#             <svg class="arrow" height="7" ng-class="{ open: isToolsOpen }" viewbox="0 0 11 7" width="11" xmlns="http://www.w3.org/2000/svg">
# <path d="M110 4L114 8 110 12" fill="none" stroke="#999" stroke-width="2" transform="rotate(90 61.25 -47.75)"></path>
# </svg>
# </button>
# </div>
# <!--
#         <div class="nav-inner__menu-item">
#           <button
#             class="nav-inner__btn nav-inner__btn-draft"
#             ng-click="toggleDraft()"
#             aria-haspopup="true"
#             aria-expanded="{{isDraftOpen}}">
#             Draft
#             <svg xmlns="http://www.w3.org/2000/svg" width="11" height="7" viewBox="0 0 11 7" class="arrow" ng-class="{ open: isDraftOpen }">
#               <path fill="none" stroke="#999" stroke-width="2" d="M110 4L114 8 110 12" transform="rotate(90 61.25 -47.75)"/>
#             </svg>
#           </button>
#         </div>
# -->
# <div class="nav-inner__menu-item">
# <a class="nav-inner__btn" href="/stats/quicklinks/" ng-class="{ active: activeTab=='quicklinks' }">Quick Links</a>
# </div>
# <!--
#         <div class="nav-inner__menu-item">
#           <a href="/stats/finals/" class="nav-inner__btn" ng-class="{ active: activeTab=='finals' }">Finals</a>
#         </div>
# -->
# <!-- <div class="nav-inner__menu-item" ng-class="{ active: activeTab=='alltime' }"><a href="/alltime/">All Time Leaders</a></div> -->
# <!-- <div class="nav-inner__menu-item" ng-class="{ active: activeTab=='allstar' }"><a ng-href="{{ allstarLink.url }}" title="{{ allstarLink.text }}">All-Star 2019</a></div> -->
# </nav> <!-- .nav-inner__menu -->
# <!-- right: search -->
# <!-- add active class to test active search state -->
# </div>
# </div>
# <!-- players dropdown -->
# <section class="drop drop-players shadow-md" ng-class="{ open: isPlayersOpen }">
# <ul class="drop-list">
# <li><a class="drop-list__link" href="/stats/players/">Players Home</a></li>
# <li><a class="drop-list__link" href="/players/">Player Index</a></li>
# <li><a class="drop-list__link" href="/stats/players/traditional/">Traditional Stats</a></li>
# <li><a class="drop-list__link" href="/stats/alltime/">All Time Summary</a></li>
# <li><a class="drop-list__link" href="/stats/players/clutch-traditional/">Clutch</a></li>
# <li><a class="drop-list__link" href="/stats/players/shots-general/">Shot Dashboard</a></li>
# <li><a class="drop-list__link" href="/stats/players/defense-dash-overall/">Defensive Dashboard</a></li>
# <li><a class="drop-list__link" href="/stats/players/transition/">Play Type</a></li>
# <li><a class="drop-list__link" href="/stats/players/catch-shoot/">Tracking</a></li>
# <li><a class="drop-list__link" href="/stats/players/shooting/">Shooting</a></li>
# <li><a class="drop-list__link" href="/stats/players/opponent-shooting/">Opponent Shooting</a></li>
# <li><a class="drop-list__link" href="/stats/players/hustle/">Hustle</a></li>
# <li><a class="drop-list__link" href="/stats/players/box-outs/">Box Outs</a></li>
# <li><a class="drop-list__link" href="/stats/players/bio/">Bios</a></li>
# <li><a class="drop-list__link" href="/stats/players/boxscores/">Box Scores</a></li>
# <li><a class="drop-list__link" href="/stats/players/boxscores-traditional/">Advanced Box Scores</a></li>
# </ul>
# </section>
# <!-- teams dropdown -->
# <section class="drop drop-teams shadow-md" ng-class="{ open: isTeamsOpen }">
# <ul class="drop-list">
# <li><a class="drop-list__link" href="/stats/teams/">Teams Home</a></li>
# <li><a class="drop-list__link" href="/stats/teams/traditional/">Traditional Stats</a></li>
# <li>
# <a class="drop-list__link" href="https://nba.com/teams"></a>                  All Teams
#
#       </li>
# <li><a class="drop-list__link" href="/stats/lineups/traditional/">Lineups</a></li>
# <li><a class="drop-list__link" href="/stats/teams/clutch-traditional/">Clutch</a></li>
# <li><a class="drop-list__link" href="/stats/teams/shots-general/">Shot Dashboard</a></li>
# <li><a class="drop-list__link" href="/stats/teams/defense-dash-overall/">Defense Dashboard</a></li>
# <li><a class="drop-list__link" href="/stats/teams/transition/">Play Type</a></li>
# <li><a class="drop-list__link" href="/stats/teams/catch-shoot/">Tracking</a></li>
# <li><a class="drop-list__link" href="/stats/teams/shooting/">Shooting</a></li>
# <li><a class="drop-list__link" href="/stats/teams/opponent-shooting/">Opponent Shooting</a></li>
# <li><a class="drop-list__link" href="/stats/teams/hustle/">Hustle Stats</a></li>
# <li><a class="drop-list__link" href="/stats/teams/box-outs/">Box Outs</a></li>
# <li><a class="drop-list__link" href="/stats/teams/boxscores/">Box Scores</a></li>
# <li><a class="drop-list__link" href="/stats/teams/boxscores-traditional/">Advanced Box Scores</a></li>
# </ul>
# </section>
# <!-- leaders dropdown -->
# <section class="drop drop-leaders shadow-md" ng-class="{ open: isLeadersOpen }">
# <ul class="drop-list">
# <li><a class="drop-list__link" href="/stats/leaders/">Official Leaders</a></li>
# <li><a class="drop-list__link" href="/stats/alltime-leaders/">All Time Leaders</a></li>
# <li ng-if="flags.isHustleMenuActive">
# <a class="drop-list__link" href="/stats/players/hustle-leaders/">Hustle Leaders</a>
# </li>
# <li><a class="drop-list__link" href="/stats/players/advanced-leaders/">Advanced Leaders</a></li>
# </ul>
# </section>
# <!-- stats 101 dropdown -->
# <section class="drop drop-stats101 shadow-md" ng-class="{ open: isStats101Open }">
# <ul class="drop-list">
# <li><a class="drop-list__link" href="/stats/history/">Franchise History</a></li>
# <li><a class="drop-list__link" href="/stats/help/statminimums/">Statistical Minimums</a></li>
# <li><a class="drop-list__link" href="/stats/help/glossary/">Glossary</a></li>
# <li><a class="drop-list__link" href="/stats/transactions/">Transactions</a></li>
# <li><a class="drop-list__link" href="/stats/fantasynews/">Fantasy News</a></li>
# <li><a class="drop-list__link" href="/stats/featuredarchive/">Articles</a></li>
# <li><a class="drop-list__link" href="/stats/spotlightarchive/">Weekly Stats Archive</a></li>
# <li><a class="drop-list__link" href="/stats/help/faq/">FAQ</a></li>
# <li><a class="drop-list__link" href="/stats/help/videostatus/">Video &amp; Tracking Status</a></li>
# <li><a class="drop-list__link" href="http://videorulebook.nba.com">Video Rulebook</a></li>
# <li><a class="drop-list__link" href="/stats/help/">Contact Us</a></li>
# </ul>
# </section>
# <!-- tools - drop down -->
# <section class="drop drop-tools shadow-md" ng-class="{ open: isToolsOpen }">
# <ul class="drop-list">
# <li><a class="drop-list__link" href="/stats/search/player-game/">Player Box Score Search</a></li>
# <li><a class="drop-list__link" href="/stats/search/team-game/">Team Box Score Search</a></li>
# <li><a class="drop-list__link" href="/stats/search/player-streak/">Player Streak Search</a></li>
# <li><a class="drop-list__link" href="/stats/search/team-streak/">Team Streak Search</a></li>
# <li><a class="drop-list__link" href="/stats/vs/">Player Compare</a></li>
# <li><a class="drop-list__link" href="/stats/fantasycompare/">Fantasy Compare</a></li>
# <li><a class="drop-list__link" href="/stats/impact/">Impact</a></li>
# <li><a class="drop-list__link" href="/stats/cumestats/">Cume Stats</a></li>
# <li><a class="drop-list__link" href="/stats/lineups/lineups-tool">Lineups Tool</a></li>
# <li><a class="drop-list__link" href="/stats/tools/media-central-game-stats/">Media Central Game Stats</a></li>
# </ul>
# </section>
# <!-- draft - drop down -->
# <section class="drop drop-draft shadow-md" ng-class="{ open: isDraftOpen }">
# <ul class="drop-list">
# <li><a class="drop-list__link" href="/stats/draft/combine/">Draft Combine</a></li>
# <li><a class="drop-list__link" href="/stats/draft/history/">Draft History</a></li>
# <li><a class="drop-list__link" href="/stats/draft/combine-spot-up/">Combine Spot Up Shooting</a></li>
# <li><a class="drop-list__link" href="/stats/draft/combine-non-stationary/">Combine Non-Stationary Shooting</a></li>
# <li><a class="drop-list__link" href="/stats/draft/combine-strength-agility/">Combine Strength &amp; Agility</a></li>
# <li><a class="drop-list__link" href="/stats/draft/combine-anthro/">Combine Anthro</a></li>
# </ul>
# </section>
# <!-- events -drop down -->
# </div>
# <nav class="stats-dropdown" ng-cloak="" ng-controller="StatsNavController" ng-show="showSiteNavigation">
# <section class="dropdown__base">
# <div class="dropdown__item">
# <h4 class="dropdown__item-header">
# <a class="dropdown__item-header__link" href="/stats/">Stats Home</a>
# </h4>
# </div>
# <!-- players: open -->
# <div class="dropdown__category--active" ng-show="isPlayerSection">
# <div class="dropdown__item" ng-click="toggleActiveMenu('player')">
# <h4 class="dropdown__item-header">
# <a class="dropdown__item-header__link">{{ player.name }} <i aria-hidden="true" class="dropdown__item-header__arrow [ fa / fa-chevron-right / show-for-large ]"></i><i aria-hidden="true" class="dropdown__item-header__arrow [ fa / fa-chevron-down / hide-for-large ]"></i></a>
# </h4>
# </div>
# </div>
# <section class="dropdown__category" ng-show="isActiveMenu.player">
# <ul class="dropdown__category-list">
# <li ng-if="player.sections.stats"><a href="/stats/player/{{ player.id }}/" ng-click="toggleNav();">Profile</a></li>
# <!-- <li ng-if="player.sections.current"><a href="/stats/player/{{ player.id }}/fantasy/" ng-click="toggleNav();">Fantasy</a></li> -->
# <li ng-if="player.sections.stats"><a href="/stats/player/{{ player.id }}/traditional/" ng-click="toggleNav();">Traditional</a></li>
# <li ng-if="player.sections.stats"><a href="/stats/player/{{ player.id }}/advanced/" ng-click="toggleNav();">Advanced</a></li>
# <li ng-if="player.sections.stats"><a href="/stats/player/{{ player.id }}/misc/" ng-click="toggleNav();">Misc</a></li>
# <li ng-if="player.sections.stats"><a href="/stats/player/{{ player.id }}/scoring/" ng-click="toggleNav();">Scoring</a></li>
# <li ng-if="player.sections.stats"><a href="/stats/player/{{ player.id }}/usage/" ng-click="toggleNav();">Usage</a></li>
# <li ng-if="player.sections.stats"><a href="/stats/player/{{ player.id }}/shooting/" ng-click="toggleNav();">Shooting</a></li>
# <li><a href="/stats/player/{{ player.id }}/career/">Career</a></li>
# <li ng-if="player.sections.boxscores &amp;&amp; player.sections.boxscoreFlag&gt;=2"><a href="/stats/player/{{ player.id }}/boxscores/" ng-click="toggleNav();">Box Scores</a></li>
# <li ng-if="player.sections.boxscores &amp;&amp; player.sections.boxscoreFlag&lt;=2"><a href="/stats/player/{{ player.id }}/boxscores-traditional/" ng-click="toggleNav();">Advanced Box Scores Traditional</a></li>
# <li ng-if="player.sections.boxscores &amp;&amp; player.sections.boxscoreFlag&lt;=2"><a href="/stats/player/{{ player.id }}/boxscores-advanced/" ng-click="toggleNav();">Advanced Box Scores Advanced</a></li>
# <li ng-if="player.sections.boxscores &amp;&amp; player.sections.boxscoreFlag&lt;=2"><a href="/stats/player/{{ player.id }}/boxscores-misc/" ng-click="toggleNav();">Advanced Box Scores Misc</a></li>
# <li ng-if="player.sections.boxscores &amp;&amp; player.sections.boxscoreFlag&lt;=2"><a href="/stats/player/{{ player.id }}/boxscores-scoring/" ng-click="toggleNav();">Advanced Box Scores Scoring</a></li>
# <li ng-if="player.sections.boxscores &amp;&amp; player.sections.boxscoreFlag&lt;=2"><a href="/stats/player/{{ player.id }}/boxscores-usage/" ng-click="toggleNav();">Advanced Box Scores Usage</a></li>
# <li ng-if="player.sections.tracking"><a href="/stats/player/{{ player.id }}/shots-dash/" ng-click="toggleNav();">Shots Dashboard</a></li>
# <li ng-if="player.sections.tracking"><a href="/stats/player/{{ player.id }}/rebounds-dash/" ng-click="toggleNav();">Rebounds Dashboard</a></li>
# <li ng-if="player.sections.tracking"><a href="/stats/player/{{ player.id }}/passes-dash/" ng-click="toggleNav();">Passes Dashboard</a></li>
# <li ng-if="player.sections.tracking"><a href="/stats/player/{{ player.id }}/defense-dash/" ng-click="toggleNav();">Defense Dashboard</a></li>
# </ul>
# </section>
# <!-- teams: open -->
# <div class="dropdown__category--active" ng-show="isTeamSection">
# <div class="dropdown__item" ng-click="toggleActiveMenu('team')">
# <h4 class="dropdown__item-header">
# <a class="dropdown__item-header__link">{{ team.city }} {{ team.name }} <i aria-hidden="true" class="dropdown__item-header__arrow [ fa / fa-chevron-right / show-for-large ]"></i><i aria-hidden="true" class="dropdown__item-header__arrow [ fa / fa-chevron-down / hide-for-large ]"></i></a>
# </h4>
# </div>
# </div>
# <section class="dropdown__category" ng-show="isActiveMenu.team">
# <ul class="dropdown__category-list">
# <li>
# <a href="https://www.nba.com/team/{{ team.id }}/" ng-click="toggleNav();">Profile</a>
# </li>
# <li ng-if="!team.isSpecial">
# <a href="https://www.nba.com/team/{{ team.id }}/traditional/" ng-click="toggleNav();">Traditional</a>
# </li>
# <li ng-if="!team.isSpecial">
# <a href="https://www.nba.com/team/{{ team.id }}/advanced/" ng-click="toggleNav();">Advanced</a>
# </li>
# <li ng-if="!team.isSpecial">
# <a href="https://www.nba.com/team/{{ team.id }}/four-factors/" ng-click="toggleNav();">Four Factors</a>
# </li>
# <li ng-if="!team.isSpecial">
# <a href="https://www.nba.com/team/{{ team.id }}/misc/" ng-click="toggleNav();">Misc</a>
# </li>
# <li ng-if="!team.isSpecial">
# <a href="https://www.nba.com/team/{{ team.id }}/scoring/" ng-click="toggleNav();">Scoring</a>
# </li>
# <li ng-if="!team.isSpecial">
# <a href="https://www.nba.com/team/{{ team.id }}/opponent/" ng-click="toggleNav();">Opponent</a>
# </li>
# <li ng-if="!team.isSpecial">
# <a href="https://www.nba.com/team/{{ team.id }}/shooting/" ng-click="toggleNav();">Shooting</a>
# </li>
# <!-- lineups -->
# <li ng-if="!team.isSpecial">
# <a href="https://www.nba.com/team/{{ team.id }}/lineups-traditional/" ng-click="toggleNav();">Lineups Traditional</a>
# </li>
# <li ng-if="!team.isSpecial">
# <a href="https://www.nba.com/team/{{ team.id }}/lineups-advanced/" ng-click="toggleNav();">Lineups Advanced</a>
# </li>
# <li ng-if="!team.isSpecial">
# <a href="https://www.nba.com/team/{{ team.id }}/lineups-four-factors/" ng-click="toggleNav();">Lineups Four Factors</a>
# </li>
# <li ng-if="!team.isSpecial">
# <a href="https://www.nba.com//team/{{ team.id }}/lineups-misc/" ng-click="toggleNav();">Lineups Misc</a>
# </li>
# <li ng-if="!team.isSpecial">
# <a href="https://www.nba.com/team/{{ team.id }}/lineups-scoring/" ng-click="toggleNav();">Lineups Scoring</a>
# </li>
# <li ng-if="!team.isSpecial">
# <a href="https://www.nba.com/team/{{ team.id }}/lineups-opponent/" ng-click="toggleNav();">Lineups Opponent</a>
# </li>
# <!-- players -->
# <li ng-if="!team.isSpecial">
# <a href="https://www.nba.com/team/{{ team.id }}/players-traditional/" ng-click="toggleNav();">Players Traditional</a>
# </li>
# <li ng-if="!team.isSpecial">
# <a href="https://www.nba.com/team/{{ team.id }}/players-advanced/" ng-click="toggleNav();">Players Advanced</a>
# </li>
# <li ng-if="!team.isSpecial">
# <a href="https://www.nba.com/team/{{ team.id }}/players-misc/" ng-click="toggleNav();">Players Misc</a>
# </li>
# <li ng-if="!team.isSpecial">
# </li>
# <li ng-if="!team.isSpecial">
# <a href="https://www.nba.com/team/{{ team.id }}/players-scoring/" ng-click="toggleNav();">Players Scoring</a>
# </li>
# <li ng-if="!team.isSpecial">
# <a href="https://www.nba.com/team/{{ team.id }}/players-usage/" ng-click="toggleNav();">Players Usage</a>
# </li>
# <!-- on off court -->
# <li ng-if="!team.isSpecial">
# <a href="https://www.nba.com/team/{{ team.id }}/onoffcourt-traditional/" ng-click="toggleNav();">On/Off Court Traditional</a>
# </li>
# <li ng-if="!team.isSpecial">
# <a href="https://www.nba.com/team/{{ team.id }}/onoffcourt-advanced/" ng-click="toggleNav();">On/Off Court Advanced</a>
# </li>
# <li ng-if="!team.isSpecial">
# <a href="https://www.nba.com/team/{{ team.id }}/onoffcourt-four-factors/" ng-click="toggleNav();">On/Off Court Four Factors</a>
# </li>
# <li ng-if="!team.isSpecial">
# <a href="https://www.nba.com/team/{{ team.id }}/onoffcourt-misc/" ng-click="toggleNav();">On/Off Court Misc</a>
# </li>
# <li ng-if="!team.isSpecial">
# <a href="https://www.nba.com/team/{{ team.id }}/onoffcourt-scoring/" ng-click="toggleNav();">On/Off Court Scoring</a>
# </li>
# <li ng-if="!team.isSpecial">
# <a href="https://www.nba.com/team/{{ team.id }}/onoffcourt-opponent/" ng-click="toggleNav();">On/Off Court Opponent</a>
# </li>
# <li ng-if="!team.isSpecial">
# <a href="https://www.nba.com/team/{{ team.id }}/onoffcourt-summary/" ng-click="toggleNav();">On/Off Court Summary</a>
# </li>
# <!-- tracking -->
# <li ng-if="!team.isSpecial">
# <a href="https://www.nba.com/team/{{ team.id }}/shots-dash/" ng-click="toggleNav();">Shots Dashboard</a>
# </li>
# <li ng-if="!team.isSpecial">
# <a href="https://www.nba.com/team/{{ team.id }}/rebounds-dash/" ng-click="toggleNav();">Rebounds Dashboard</a>
# </li>
# <li ng-if="!team.isSpecial">
# <a href="https://www.nba.com/team/{{ team.id }}/passes-dash/" ng-click="toggleNav();">Passes Dashboard</a>
# </li>
# <!-- history -->
# <li>
# <a href="https://www.nba.com/team/{{ team.id }}/boxscores/" ng-click="toggleNav();">Box Scores</a>
# </li>
# <li ng-if="!team.isSpecial">
# <a href="https://www.nba.com/team/{{ team.id }}/boxscores-traditional/" ng-click="toggleNav();">Advanced Box Scores Traditional</a>
# </li>
# <li ng-if="!team.isSpecial">
# <a href="https://www.nba.com/team/{{ team.id }}/boxscores-advanced/" ng-click="toggleNav();">Advanced Box Scores Advanced</a>
# </li>
# <li ng-if="!team.isSpecial">
# <a href="https://www.nba.com/team/{{ team.id }}/boxscores-four-factors/" ng-click="toggleNav();">Advanced Box Scores Four Factors</a>
# </li>
# <li ng-if="!team.isSpecial">
# <a href="https://www.nba.com/team/{{ team.id }}/boxscores-misc/" ng-click="toggleNav();">Advanced Box Scores Misc</a>
# </li>
# <li ng-if="!team.isSpecial" s="">
# <a href="https://www.nba.com/team/{{ team.id }}/boxscores-scoring/" ng-click="toggleNav();">Advanced Box Scores Scoring</a>
# </li>
# <li>
# <a href="https://www.nba.com/team/{{ team.id }}/seasons/" ng-click="toggleNav();">Seasons</a>
# </li>
# <li>
# <a href="https://www.nba.com/team/{{ team.id }}/yearoveryear/" ng-click="toggleNav();">Year Over Year</a>
# </li>
# <li>
# <a href="https://www.nba.com/team/{{ team.id }}/franchise-leaders/" ng-click="toggleNav();">Franchise Leaders</a>
# </li>
# <li>
# <a href="https://www.nba.com/team/{{ team.id }}/historic-roster/" ng-click="toggleNav();">Historic Roster</a>
# </li>
# </ul>
# </section>
# <!-- on off: open -->
# <div class="dropdown__category--active" ng-show="isOnOffSection">
# <div class="dropdown__item" ng-click="toggleActiveMenu('onoff')">
# <h4 class="dropdown__item-header">
# <a class="dropdown__item-header__link">On Off Court Compare <i aria-hidden="true" class="dropdown__item-header__arrow [ fa / fa-chevron-right / show-for-large ]"></i><i aria-hidden="true" class="dropdown__item-header__arrow [ fa / fa-chevron-down / hide-for-large ]"></i></a>
# </h4>
# </div>
# </div>
# <section class="dropdown__category" ng-show="isActiveMenu.onoff">
# <ul class="dropdown__category-list">
# <li><a href="/stats/vs/" ng-click="toggleNav();">Traditional</a></li>
# <li><a href="/stats/vs/advanced/" ng-click="toggleNav();">Advanced</a></li>
# <li><a href="/stats/vs/misc/" ng-click="toggleNav();">Misc</a></li>
# <li><a href="/stats/vs/scoring/" ng-click="toggleNav();">Scoring</a></li>
# <li><a href="/stats/vs/four-factors/" ng-click="toggleNav();">Four Factors</a></li>
# <li><a href="/stats/vs/opponent/" ng-click="toggleNav();">Opponent</a></li>
# </ul>
# </section>
# <!-- game: open -->
# <div class="dropdown__category--active" ng-show="isGameSection">
# <div class="dropdown__item" ng-click="toggleActiveMenu('game')">
# <h4 class="dropdown__item-header">
# <a class="dropdown__item-header__link">{{ game.info }} <i aria-hidden="true" class="dropdown__item-header__arrow [ fa / fa-chevron-right / show-for-large ]"></i><i aria-hidden="true" class="dropdown__item-header__arrow [ fa / fa-chevron-down / hide-for-large ]"></i></a>
# </h4>
# </div>
# </div>
# <section class="dropdown__category" ng-show="isActiveMenu.game">
# <ul class="dropdown__category-list">
# <li>
# <a href="https://nba.com/game/{{ game.id }}/">Box Score</a>
# </li>
# <li>
# <a href="https://nba.com/game/{{ game.id }}/advanced/" ng-click="toggleNav();" ng-show="game.sections.advancedStats">Advanced</a>
# </li>
# <li>
# <a href="https://nba.com/game/{{ game.id }}/misc/" ng-click="toggleNav();" ng-show="game.sections.advancedStats">Misc</a>
# </li>
# <li>
# <a href="https://nba.com/game/{{ game.id }}/scoring/" ng-click="toggleNav();" ng-show="game.sections.advancedStats">Scoring</a>
# </li>
# <li>
# <a href="https://nba.com/game/game/{{ game.id }}/usage/" ng-click="toggleNav();" ng-show="game.sections.advancedStats">Usage</a>
# </li>
# <li>
# <a href="https://nba.com/game/{{ game.id }}/four-factors/" ng-click="toggleNav();" ng-show="game.sections.advancedStats">Four Factors</a>
# </li>
# <li>
# <a href="https://nba.com/game/{{ game.id }}/tracking/" ng-click="toggleNav();" ng-show="game.sections.playerTracking">Player Tracking</a>
# </li>
# <li>
# <a href="https://nba.com/game/{{ game.id }}/playbyplay/" ng-click="toggleNav();" ng-show="game.sections.playByPlay">Play By Play</a>
# </li>
# <li>
# <a href="https://nba.com/game/{{ game.id }}/shotchart/" ng-click="toggleNav();" ng-show="game.sections.shotchart">Shotchart</a>
# </li>
# <li>
# <a href="https://nba.com/game/{{ game.id }}/charts/" ng-click="toggleNav();" ng-show="game.sections.gameCharts">Game Charts</a>
# </li>
# <li>
# <a href="https://nba.com/game/{{ game.id }}/hustle/" ng-click="toggleNav();" ng-show="game.sections.hustle">Hustle</a>
# </li>
# </ul>
# </section>
# <!-- fantasy: open -->
# <div class="dropdown__category--active" ng-show="isFantasySection">
# <div class="dropdown__item" ng-click="toggleActiveMenu('fantasy')">
# <h4 class="dropdown__item-header">
# <a class="dropdown__item-header__link">Fantasy Compare <i aria-hidden="true" class="dropdown__item-header__arrow [ fa / fa-chevron-right / show-for-large ]"></i><i aria-hidden="true" class="dropdown__item-header__arrow [ fa / fa-chevron-down / hide-for-large ]"></i></a>
# </h4>
# </div>
# </div>
# <section class="dropdown__category" ng-show="isActiveMenu.fantasy">
# <ul class="dropdown__category-list">
# <li><a href="/stats/fantasycompare/" ng-click="toggleNav();">Traditional</a></li>
# <li><a href="/stats/fantasycompare/advanced/" ng-click="toggleNav();">Advanced</a></li>
# <li><a href="/stats/fantasycompare/misc/" ng-click="toggleNav();">Misc</a></li>
# <li><a href="/stats/fantasycompare/scoring/" ng-click="toggleNav();">Scoring</a></li>
# </ul>
# </section>
# <!-- impact: open -->
# <div class="dropdown__category--active" ng-show="isImpactSection">
# <div class="dropdown__item" ng-click="toggleActiveMenu('impact')">
# <h4 class="dropdown__item-header">
# <a class="dropdown__item-header__link">Impact <i aria-hidden="true" class="dropdown__item-header__arrow [ fa / fa-chevron-right / show-for-large ]"></i><i aria-hidden="true" class="dropdown__item-header__arrow [ fa / fa-chevron-down / hide-for-large ]"></i></a>
# </h4>
# </div>
# </div>
# <section class="dropdown__category" ng-show="isActiveMenu.impact">
# <ul class="dropdown__category-list">
# <li><a href="/stats/impact/{{ impact }}" ng-click="toggleNav();">Traditional</a></li>
# <li><a href="/stats/impact/advanced/{{ impact }}" ng-click="toggleNav();">Advanced</a></li>
# <li><a href="/stats/impact/misc/{{ impact }}" ng-click="toggleNav();">Misc</a></li>
# <li><a href="/stats/impact/scoring/{{ impact }}" ng-click="toggleNav();">Scoring</a></li>
# <li><a href="/stats/impact/four-factors/{{ impact }}" ng-click="toggleNav();">Four Factors</a></li>
# <!-- <li><a href="/stats/impact/opponent/{{ impact }}" ng-click="toggleNav();">Opponent</a></li> -->
# <!-- <li><a href="/stats/impact/usage/{{ impact }}" ng-click="toggleNav();">Usage</a></li> -->
# <li><a href="/stats/impact/defense/{{ impact }}" ng-click="toggleNav();">Defense</a></li>
# </ul>
# </section>
# <div class="stats-dropdown__level--base__top"></div>
# <!-- players -->
# <div class="dropdown__item" ng-class="{'dropdown__item--active':isCat.players}" ng-click="toggleCat('players')">
# <h4 class="dropdown__item-header">Players <i aria-hidden="true" class="dropdown__item-header__arrow [ fa / fa-chevron-right / show-for-large ]"></i><i aria-hidden="true" class="dropdown__item-header__arrow [ fa / fa-chevron-down / hide-for-large ]"></i></h4>
# </div>
# <!-- players - category -->
# <section class="dropdown__category" ng-show="isCat.players">
# <ul class="dropdown__category-list">
# <li><a href="/stats/players/">Players Home</a></li>
# <li><a href="/stats/players/list/">Player Index</a></li>
# <li><a href="/stats/players/traditional/">Traditional Stats</a></li>
# <li><a href="/stats/leaders/">Regular Season Leaders</a></li>
# <li ng-if="flags.isHustleMenuActive"><a href="/stats/players/hustle-leaders/">Hustle Leaders</a></li>
# <li><a href="/stats/players/advanced-leaders/">Advanced Leaders</a></li>
# <li><a href="/stats/alltime/">All Time Leaders</a></li>
# <!-- players / general -->
# <li class="dropdown__item" ng-class="{'dropdown__item--active': isPlayersSub.general}" ng-click="toggleSub(isPlayersSub, 'general')">
# <a class="dropdown__item-header">General <i aria-hidden="true" class="dropdown__item-header__arrow [ fa / fa-chevron-right / show-for-large ]"></i><i aria-hidden="true" class="dropdown__item-header__arrow [ fa / fa-chevron-down / hide-for-large ]"></i></a>
# </li>
# <section class="dropdown__subcategory" ng-show="isPlayersSub.general">
# <ul class="dropdown__subcategory-list">
# <li><a href="/stats/players/traditional/">Traditional</a></li>
# <li><a href="/stats/players/advanced/">Advanced</a></li>
# <li><a href="/stats/players/misc/">Misc</a></li>
# <li><a href="/stats/players/scoring/">Scoring</a></li>
# <li><a href="/stats/players/usage/">Usage</a></li>
# <li><a href="/stats/players/opponent/">Opponent</a></li>
# <li><a href="/stats/players/defense/">Defense</a></li>
# <li><a href="/stats/players/estimated-advanced/">Estimated Advanced</a></li>
# </ul>
# </section>
# <!-- players / clutch -->
# <li class="dropdown__item" ng-class="{'dropdown__item--active': isPlayersSub.clutch}" ng-click="toggleSub(isPlayersSub, 'clutch')">
# <a class="dropdown__item-header">Clutch <i aria-hidden="true" class="dropdown__item-header__arrow [ fa / fa-chevron-right / show-for-large ]"></i><i aria-hidden="true" class="dropdown__item-header__arrow [ fa / fa-chevron-down / hide-for-large ]"></i></a>
# </li>
# <section class="dropdown__subcategory" ng-show="isPlayersSub.clutch">
# <ul class="dropdown__subcategory-list">
# <li><a href="/stats/players/clutch-traditional/">Clutch Traditional</a></li>
# <li><a href="/stats/players/clutch-advanced/">Clutch Advanced</a></li>
# <li><a href="/stats/players/clutch-misc/">Clutch Misc</a></li>
# <li><a href="/stats/players/clutch-scoring/">Clutch Scoring</a></li>
# <li><a href="/stats/players/clutch-usage/">Clutch Usage</a></li>
# </ul>
# </section>
# <!-- players / defense -->
# <li class="dropdown__item" ng-class="{'dropdown__item--active': isPlayersSub.defense}" ng-click="toggleSub(isPlayersSub, 'defense')">
# <a class="dropdown__item-header">Defense <i aria-hidden="true" class="dropdown__item-header__arrow [ fa / fa-chevron-right / show-for-large ]"></i><i aria-hidden="true" class="dropdown__item-header__arrow [ fa / fa-chevron-down / hide-for-large ]"></i></a>
# </li>
# <section class="dropdown__subcategory" ng-show="isPlayersSub.defense">
# <ul class="dropdown__subcategory-list">
# <li><a href="/stats/players/defense/">Defense Overall</a></li>
# <li><a href="/stats/players/defense-dash-overall/">Defending Shots Overall</a></li>
# <li><a href="/stats/players/defense-dash-3pt/">Defending 3 Pointers</a></li>
# <li><a href="/stats/players/defense-dash-2pt/">Defending 2 Pointers</a></li>
# <li><a href="/stats/players/defense-dash-lt6/">Defending Less Than 6 FT</a></li>
# <li><a href="/stats/players/defense-dash-lt10/">Defending Less Than 10 FT</a></li>
# <li><a href="/stats/players/defense-dash-gt15/">Defending More Than 15 FT</a></li>
# <li><a href="/stats/players/opponent-shooting/">Opponent Shooting</a></li>
# <li><a href="/stats/players/isolation/?OD=defensive">By Play Type</a></li>
# </ul>
# </section>
# <!-- players / playtype -->
# <li class="dropdown__item" ng-class="{'dropdown__item--active': isPlayersSub.playtype}" ng-click="toggleSub(isPlayersSub, 'playtype')">
# <a class="dropdown__item-header">Play Type <i aria-hidden="true" class="dropdown__item-header__arrow [ fa / fa-chevron-right / show-for-large ]"></i><i aria-hidden="true" class="dropdown__item-header__arrow [ fa / fa-chevron-down / hide-for-large ]"></i></a>
# </li>
# <section class="dropdown__subcategory" ng-show="isPlayersSub.playtype">
# <ul class="dropdown__subcategory-list">
# <li><a href="/stats/players/transition/">Transition</a></li>
# <li><a href="/stats/players/isolation/">Isolation</a></li>
# <li><a href="/stats/players/ball-handler/">Ball Handler</a></li>
# <li><a href="/stats/players/roll-man/">Roll Man</a></li>
# <li><a href="/stats/players/playtype-post-up/">Post Up</a></li>
# <li><a href="/stats/players/spot-up/">Spot Up</a></li>
# <li><a href="/stats/players/hand-off/">Hand Off</a></li>
# <li><a href="/stats/players/cut/">Cut</a></li>
# <li><a href="/stats/players/off-screen/">Off Screen</a></li>
# <li><a href="/stats/players/putbacks/">Put Backs</a></li>
# <li><a href="/stats/players/playtype-misc/">Misc</a></li>
# </ul>
# </section>
# <!-- players / tracking -->
# <li class="dropdown__item" ng-class="{'dropdown__item--active': isPlayersSub.tracking}" ng-click="toggleSub(isPlayersSub, 'tracking')">
# <a class="dropdown__item-header">Tracking <i aria-hidden="true" class="dropdown__item-header__arrow [ fa / fa-chevron-right / show-for-large ]"></i><i aria-hidden="true" class="dropdown__item-header__arrow [ fa / fa-chevron-down / hide-for-large ]"></i></a>
# </li>
# <section class="dropdown__subcategory" ng-show="isPlayersSub.tracking">
# <ul class="dropdown__subcategory-list">
# <li><a href="/stats/players/catch-shoot/">Catch &amp; Shoot</a></li>
# <li><a href="/stats/players/defensive-impact/">Defensive Impact</a></li>
# <li><a href="/stats/players/drives/">Drives</a></li>
# <li><a href="/stats/players/passing/">Passing</a></li>
# <li><a href="/stats/players/touches/">Touches</a></li>
# <li><a href="/stats/players/pullup/">Pull Up Shooting</a></li>
# <li><a href="/stats/players/rebounding/">Rebounding</a></li>
# <li><a href="/stats/players/offensive-rebounding/">Offensive Rebounding</a></li>
# <li><a href="/stats/players/defensive-rebounding/">Defensive Rebounding</a></li>
# <li><a href="/stats/players/shooting-efficiency/">Shooting Efficiency</a></li>
# <li><a href="/stats/players/speed-distance/">Speed &amp; Distance</a></li>
# <li><a href="/stats/players/elbow-touch/">Elbow Touches</a></li>
# <li><a href="/stats/players/tracking-post-ups/">Post Ups</a></li>
# <li><a href="/stats/players/paint-touch/">Paint Touches</a></li>
# </ul>
# </section>
# <!-- players / shots -->
# <li class="dropdown__item" ng-class="{'dropdown__item--active': isPlayersSub.shots}" ng-click="toggleSub(isPlayersSub, 'shots')">
# <a class="dropdown__item-header">Shooting <i aria-hidden="true" class="dropdown__item-header__arrow [ fa / fa-chevron-right / show-for-large ]"></i><i aria-hidden="true" class="dropdown__item-header__arrow [ fa / fa-chevron-down / hide-for-large ]"></i></a>
# </li>
# <section class="dropdown__subcategory" ng-show="isPlayersSub.shots">
# <ul class="dropdown__subcategory-list">
# <li><a href="/stats/players/shots-general/">Shots by General Range</a></li>
# <li><a href="/stats/players/shots-shotclock/">Shots by Shotclock</a></li>
# <li><a href="/stats/players/shots-dribbles/">Shots by Dribbles</a></li>
# <li><a href="/stats/players/shots-touch-time/">Shots by Touch Time</a></li>
# <li><a href="/stats/players/shots-closest-defender/">Shots by Closest Defender</a></li>
# <li><a href="/stats/players/shots-closest-defender-10/">Shots by Closest Defender (+10 FT)</a></li>
# <li><a href="/stats/players/shooting/">Shooting</a></li>
# <li><a href="/stats/players/opponent-shooting/">Opponent Shooting</a></li>
# </ul>
# </section>
# <li><a href="/stats/players/hustle/">Hustle Stats</a></li>
# <li><a href="/stats/players/box-outs/">Box Outs</a></li>
# <li><a href="/stats/players/bio/">Bios</a></li>
# <li><a href="/stats/players/boxscores/">Box Scores</a></li>
# <!-- players / advanced game logs -->
# <li class="dropdown__item" ng-class="{'dropdown__item--active': isPlayersSub.advboxscores}" ng-click="toggleSub(isPlayersSub, 'advboxscores')">
# <a class="dropdown__item-header">Advanced Box Scores <i aria-hidden="true" class="dropdown__item-header__arrow [ fa / fa-chevron-right / show-for-large ]"></i><i aria-hidden="true" class="dropdown__item-header__arrow [ fa / fa-chevron-down / hide-for-large ]"></i></a>
# </li>
# <section class="dropdown__subcategory" ng-show="isPlayersSub.advboxscores">
# <ul class="dropdown__subcategory-list">
# <li><a href="/stats/players/boxscores-traditional/">Traditional</a></li>
# <li><a href="/stats/players/boxscores-advanced/">Advanced</a></li>
# <li><a href="/stats/players/boxscores-misc/">Misc</a></li>
# <li><a href="/stats/players/boxscores-scoring/">Scoring</a></li>
# <li><a href="/stats/players/boxscores-usage/">Usage</a></li>
# </ul>
# </section>
# </ul>
# </section>
# <!-- teams -->
# <div class="dropdown__item" ng-class="{'dropdown__item--active':isCat.teams}" ng-click="toggleCat('teams')">
# <h4 class="dropdown__item-header">Teams <i aria-hidden="true" class="dropdown__item-header__arrow [ fa / fa-chevron-right / show-for-large ]"></i><i aria-hidden="true" class="dropdown__item-header__arrow [ fa / fa-chevron-down / hide-for-large ]"></i></h4>
# </div>
# <section class="dropdown__category" ng-show="isCat.teams">
# <ul class="dropdown__category-list">
# <li><a href="/stats/teams/">Teams Home</a></li>
# <!-- teams / general -->
# <li class="dropdown__item" ng-class="{'dropdown__item--active': isTeamsSub.list}" ng-click="toggleSub(isTeamsSub, 'list')">
# <a class="dropdown__item-header">All Teams <i aria-hidden="true" class="dropdown__item-header__arrow [ fa / fa-chevron-right / show-for-large ]"></i><i aria-hidden="true" class="dropdown__item-header__arrow [ fa / fa-chevron-down / hide-for-large ]"></i></a>
# </li>
# <section class="dropdown__subcategory" ng-show="isTeamsSub.list">
# <ul class="dropdown__subcategory-list">
# <li ng-repeat="t in teams">
# <a href="https://www.nba.com/team/{{ t.id }}/"></a>{{ t.city }} {{ t.name }}
#                         </li>
# <li ng-repeat="t in teams">
# </li>
# </ul>
# </section>
# <li><a href="/stats/teams/traditional/">Traditional Stats</a></li>
# <li ng-if="flags.isHustleMenuActive"><a href="/stats/teams/hustle-leaders/">Hustle Leaders</a></li>
# <li><a href="/stats/teams/advanced-leaders/">Advanced Leaders</a></li>
# <!-- teams / general -->
# <li class="dropdown__item" ng-class="{'dropdown__item--active': isTeamsSub.general}" ng-click="toggleSub(isTeamsSub, 'general')">
# <a class="dropdown__item-header">General <i aria-hidden="true" class="dropdown__item-header__arrow [ fa / fa-chevron-right / show-for-large ]"></i><i aria-hidden="true" class="dropdown__item-header__arrow [ fa / fa-chevron-down / hide-for-large ]"></i></a>
# </li>
# <section class="dropdown__subcategory" ng-show="isTeamsSub.general">
# <ul class="dropdown__subcategory-list">
# <li><a href="/stats/teams/traditional/">Traditional</a></li>
# <li><a href="/stats/teams/advanced/">Advanced</a></li>
# <li><a href="/stats/teams/misc/">Misc</a></li>
# <li><a href="/stats/teams/four-factors/">Four Factors</a></li>
# <li><a href="/stats/teams/scoring/">Scoring</a></li>
# <li><a href="/stats/teams/opponent/">Opponent</a></li>
# <li><a href="/stats/teams/defense/">Defense</a></li>
# <li><a href="/stats/teams/estimated-advanced/">Estimated Advanced</a></li>
# </ul>
# </section>
# <!-- clutch -->
# <li class="dropdown__item" ng-class="{'dropdown__item--active': isTeamsSub.clutch}" ng-click="toggleSub(isTeamsSub, 'clutch')">
# <a class="dropdown__item-header">Clutch <i aria-hidden="true" class="dropdown__item-header__arrow [ fa / fa-chevron-right / show-for-large ]"></i><i aria-hidden="true" class="dropdown__item-header__arrow [ fa / fa-chevron-down / hide-for-large ]"></i></a>
# </li>
# <section class="dropdown__subcategory" ng-show="isTeamsSub.clutch">
# <ul class="dropdown__subcategory-list">
# <li><a href="/stats/teams/clutch-traditional/">Clutch Traditional</a></li>
# <li><a href="/stats/teams/clutch-advanced/">Clutch Advanced</a></li>
# <li><a href="/stats/teams/clutch-misc/">Clutch Misc</a></li>
# <li><a href="/stats/teams/clutch-four-factors/">Clutch Four Factors</a></li>
# <li><a href="/stats/teams/clutch-scoring/">Clutch Scoring</a></li>
# <li><a href="/stats/teams/clutch-opponent/">Clutch Opponent</a></li>
# </ul>
# </section>
# <!-- teams / defense -->
# <li class="dropdown__item" ng-class="{'dropdown__item--active': isTeamsSub.defense}" ng-click="toggleSub(isTeamsSub, 'defense')">
# <a class="dropdown__item-header">Defense <i aria-hidden="true" class="dropdown__item-header__arrow [ fa / fa-chevron-right / show-for-large ]"></i><i aria-hidden="true" class="dropdown__item-header__arrow [ fa / fa-chevron-down / hide-for-large ]"></i></a>
# </li>
# <section class="dropdown__subcategory" ng-show="isTeamsSub.defense">
# <ul class="dropdown__subcategory-list">
# <li><a href="/stats/teams/defense/">Defense Overall</a></li>
# <li><a href="/stats/teams/defense-dash-overall/">Defending Shots Overall</a></li>
# <li><a href="/stats/teams/defense-dash-3pt/">Defending 3 Pointers</a></li>
# <li><a href="/stats/teams/defense-dash-2pt/">Defending 2 Pointers</a></li>
# <li><a href="/stats/teams/defense-dash-lt6/">Defending Less Than 6 FT</a></li>
# <li><a href="/stats/teams/defense-dash-lt10/">Defending Less Than 10 FT</a></li>
# <li><a href="/stats/teams/defense-dash-gt15/">Defending More Than 15 FT</a></li>
# <li><a href="/stats/teams/opponent-shooting/">Overall Opponent Shooting</a></li>
# <li><a href="/stats/teams/isolation/?OD=defensive">By Play Type</a></li>
# </ul>
# </section>
# <!-- teams / playtype -->
# <li class="dropdown__item" ng-class="{'dropdown__item--active': isTeamsSub.playtype}" ng-click="toggleSub(isTeamsSub, 'playtype')">
# ...
# <li><a data-type-beta="hustle-leaders" href="/stats/players/hustle-leaders/"><span>Hustle Leaders</span></a></li>
# <li><a data-type-beta="general" href="/stats/players/traditional/"><span>General</span></a></li>
# <li><a data-type-beta="clutch" href="/stats/players/clutch-traditional/"><span>Clutch</span></a></li>
# <li><a data-type-beta="playtype" href="/stats/players/isolation/"><span>Playtype</span></a></li>
# <li><a data-type-beta="tracking" href="/stats/players/drives/"><span>Tracking</span></a></li>
# <li><a data-type-beta="def-dash" href="/stats/players/defense-dash-overall/"><span>Defense Dashboard</span></a></li>
# <li><a data-type-beta="shot-dash" href="/stats/players/shots-general/"><span>Shot Dashboard</span></a></li>
# <li><a data-type-beta="boxscores" href="/stats/players/boxscores/"><span>Box Scores</span></a></li>
# <li><a data-type-beta="adv-boxscores" href="/stats/players/boxscores-traditional/"><span>Advanced Box Scores</span></a></li>
# <li><a data-type-beta="shooting" href="/stats/players/shooting/"><span>Shooting</span></a></li>
# <li><a data-type-beta="opponent-shooting" href="/stats/players/opponent-shooting/"><span>Opponent Shooting</span></a></li>
# <li><a data-type-beta="hustle" href="/stats/players/hustle/"><span>Hustle</span></a></li>
# <li><a data-type-beta="box-outs" href="/stats/players/box-outs/"><span>Box Outs</span></a></li>
# <li><a data-type-beta="alltime-landing" href="/stats/alltime/"><span>All Time Summary</span></a></li>
# <li><a data-type-beta="alltime-leaders" href="/stats/alltime-leaders/"><span>All Time Leaders</span></a></li>
# <li><a data-type-beta="bios" href="/stats/players/bio/"><span>Bios</span></a></li>
# <li><a data-type-beta="players-list" href="/stats/players/list"><span>Players List</span></a></li>
# </ul>
# </section>
# <section class="tertiary-nav-component" ng-show="beta==='general'">
# <div class="toggle-nav-component__button" ng-click="showGamma=!showGamma; showAlpha=false; showBeta=false;">
# <span ng-class="{ active: showGamma }">{{ gammaText }}</span>
# </div>
# <ul class="tertiary-nav-component__dropdown" ng-show="showGamma">
# <li><a data-type-gamma="traditional" href="/stats/players/traditional/"><span>Traditional</span></a></li>
# <li><a data-type-gamma="advanced" href="/stats/players/advanced/"><span>Advanced</span></a></li>
# <li><a data-type-gamma="misc" href="/stats/players/misc/"><span>Misc</span></a></li>
# <li><a data-type-gamma="scoring" href="/stats/players/scoring/"><span>Scoring</span></a></li>
# <li><a data-type-gamma="usage" href="/stats/players/usage/"><span>Usage</span></a></li>
# <li><a data-type-gamma="opponent" href="/stats/players/opponent/"><span>Opponent</span></a></li>
# <li><a data-type-gamma="defense" href="/stats/players/defense/"><span>Defense</span></a></li>
# <li><a data-type-gamma="estimated-advanced" href="/stats/players/estimated-advanced/"><span>Estimated Advanced</span></a></li>
# </ul>
# </section>
# <section class="tertiary-nav-component" ng-show="beta==='clutch'">
# <div class="toggle-nav-component__button" ng-click="showGamma=!showGamma; showAlpha=false; showBeta=false;">
# <span ng-class="{ active: showGamma }">{{ gammaText }}</span>
# </div>
# <ul class="tertiary-nav-component__dropdown" ng-show="showGamma">
# <li><a data-type-gamma="clutch-traditional" href="/stats/players/clutch-traditional/"><span>Traditional</span></a></li>
# <li><a data-type-gamma="clutch-advanced" href="/stats/players/clutch-advanced/"><span>Advanced</span></a></li>
# <li><a data-type-gamma="clutch-misc" href="/stats/players/clutch-misc/"><span>Misc</span></a></li>
# <li><a data-type-gamma="clutch-scoring" href="/stats/players/clutch-scoring/"><span>Scoring</span></a></li>
# <li><a data-type-gamma="clutch-usage" href="/stats/players/clutch-usage/"><span>Usage</span></a></li>
# </ul>
# </section>
# <section class="tertiary-nav-component" ng-show="beta==='playtype'">
# <div class="toggle-nav-component__button" ng-click="showGamma=!showGamma; showAlpha=false; showBeta=false;">
# <span ng-class="{ active: showGamma }">{{ gammaText }}</span>
# </div>
# <ul class="tertiary-nav-component__dropdown" ng-show="showGamma">
# <li><a data-type-gamma="transition" href="/stats/players/transition/"><span>Transition</span></a></li>
# <li><a data-type-gamma="isolation" href="/stats/players/isolation/"><span>Isolation</span></a></li>
# <li><a data-type-gamma="ball-handler" href="/stats/players/ball-handler/"><span>Pick &amp; Roll Ball Handler</span></a></li>
# <li><a data-type-gamma="roll-man" href="/stats/players/roll-man/"><span>Pick &amp; Roll Roll Man</span></a></li>
# <li><a data-type-gamma="post-up" href="/stats/players/playtype-post-up/"><span>Post Up</span></a></li>
# <li><a data-type-gamma="spot-up" href="/stats/players/spot-up/"><span>Spot Up</span></a></li>
# <li><a data-type-gamma="hand-off" href="/stats/players/hand-off/"><span>Handoff</span></a></li>
# <li><a data-type-gamma="cut" href="/stats/players/cut/"><span>Cut</span></a></li>
# <li><a data-type-gamma="off-screen" href="/stats/players/off-screen/"><span>Off Screen</span></a></li>
# <li><a data-type-gamma="putbacks" href="/stats/players/putbacks/"><span>Putbacks</span></a></li>
# <li><a data-type-gamma="playtype-misc" href="/stats/players/playtype-misc/"><span>Misc</span></a></li>
# </ul>
# </section>
# <section class="tertiary-nav-component" ng-show="beta==='tracking'">
# <div class="toggle-nav-component__button" ng-click="showGamma=!showGamma; showAlpha=false; showBeta=false;">
# <span ng-class="{ active: showGamma }">{{ gammaText }}</span>
# </div>
# <ul class="tertiary-nav-component__dropdown" ng-show="showGamma">
# <li><a data-type-gamma="drives" href="/stats/players/drives/"><span>Drives</span></a></li>
# <li><a data-type-gamma="defensive-impact" href="/stats/players/defensive-impact/"><span>Defensive Impact</span></a></li>
# <li><a data-type-gamma="catch-shoot" href="/stats/players/catch-shoot/"><span>Catch &amp; Shoot</span></a></li>
# <li><a data-type-gamma="passing" href="/stats/players/passing/"><span>Passing</span></a></li>
# <li><a data-type-gamma="touches" href="/stats/players/touches/"><span>Touches</span></a></li>
# <li><a data-type-gamma="pullup" href="/stats/players/pullup/"><span>Pull Up Shooting</span></a></li>
# <li><a data-type-gamma="rebounding" href="/stats/players/rebounding/"><span>Rebounding</span></a></li>
# <li><a data-type-gamma="offensive-rebounding" href="/stats/players/offensive-rebounding/"><span>Offensive Rebounding</span></a></li>
# <li><a data-type-gamma="defensive-rebounding" href="/stats/players/defensive-rebounding/"><span>Defensive Rebounding</span></a></li>
# <li><a data-type-gamma="shooting-efficiency" href="/stats/players/shooting-efficiency/"><span>Shooting Efficiency</span></a></li>
# <li><a data-type-gamma="speed-distance" href="/stats/players/speed-distance/"><span>Speed &amp; Distance</span></a></li>
# <li><a data-type-gamma="elbow-touch" href="/stats/players/elbow-touch/"><span>Elbow Touches</span></a></li>
# <li><a data-type-gamma="post-ups" href="/stats/players/tracking-post-ups/"><span>Post Ups</span></a></li>
# <li><a data-type-gamma="paint-touch" href="/stats/players/paint-touch/"><span>Paint Touches</span></a></li>
# </ul>
# </section>
# <section class="tertiary-nav-component" ng-show="beta==='def-dash'">
# <div class="toggle-nav-component__button" ng-click="showGamma=!showGamma; showAlpha=false; showBeta=false;">
# <span ng-class="{ active: showGamma }">{{ gammaText }}</span>
# </div>
# <ul class="tertiary-nav-component__dropdown" ng-show="showGamma">
# <li><a data-type-gamma="def-overall" href="/stats/players/defense-dash-overall/"><span>Overall</span></a></li>
# <li><a data-type-gamma="def-3pt" href="/stats/players/defense-dash-3pt/"><span>3 Pointers</span></a></li>
# <li><a data-type-gamma="def-2pt" href="/stats/players/defense-dash-2pt/"><span>2 Pointers</span></a></li>
# <li><a data-type-gamma="def-lt6" href="/stats/players/defense-dash-lt6/"><span>&lt; 6ft.</span></a></li>
# <li><a data-type-gamma="def-lt10" href="/stats/players/defense-dash-lt10/"><span>&lt; 10ft.</span></a></li>
# <li><a data-type-gamma="def-gt15" href="/stats/players/defense-dash-gt15/"><span>&gt; 15ft.</span></a></li>
# </ul>
# </section>
# <section class="tertiary-nav-component" ng-show="beta==='shot-dash'">
# <div class="toggle-nav-component__button" ng-click="showGamma=!showGamma; showAlpha=false; showBeta=false;">
# <span ng-class="{ active: showGamma }">{{ gammaText }}</span>
# </div>
# <ul class="tertiary-nav-component__dropdown" ng-show="showGamma">
# <li><a data-type-gamma="shot-general" href="/stats/players/shots-general/"><span>General</span></a></li>
# <li><a data-type-gamma="shot-shotclock" href="/stats/players/shots-shotclock/"><span>Shotclock</span></a></li>
# <li><a data-type-gamma="shot-dribbles" href="/stats/players/shots-dribbles/"><span>Dribbles</span></a></li>
# <li><a data-type-gamma="shot-touch-time" href="/stats/players/shots-touch-time/"><span>Touch Time</span></a></li>
# <li><a data-type-gamma="shot-closest-def" href="/stats/players/shots-closest-defender/"><span>Closest Defender</span></a></li>
# <li><a data-type-gamma="shot-closest-def10" href="/stats/players/shots-closest-defender-10/"><span>Closest Defender +10</span></a></li>
# </ul>
# </section>
# <section class="tertiary-nav-component" ng-show="beta==='adv-boxscores'">
# <div class="toggle-nav-component__button" ng-click="showGamma=!showGamma; showAlpha=false; showBeta=false;">
# <span ng-class="{ active: showGamma }">{{ gammaText }}</span>
# </div>
# <ul class="tertiary-nav-component__dropdown" ng-show="showGamma">
# <li><a data-type-gamma="traditional" href="/stats/players/boxscores-traditional/"><span>Traditional</span></a></li>
# <li><a data-type-gamma="advanced" href="/stats/players/boxscores-advanced/"><span>Advanced</span></a></li>
# <li><a data-type-gamma="misc" href="/stats/players/boxscores-misc/"><span>Misc</span></a></li>
# <li><a data-type-gamma="scoring" href="/stats/players/boxscores-scoring/"><span>Scoring</span></a></li>
# <li><a data-type-gamma="usage" href="/stats/players/boxscores-usage/"><span>Usage</span></a></li>
# </ul>
# </section>
# <section class="tertiary-nav-component">
# <div class="toggle-nav-component__caret">
# <i aria-hidden="true" class="fa fa-caret-down"></i>
# </div>
# </section>
# </nav>
# <section class="columns / small-12 / tertiary-nav-overlay" ng-class="{ active: showAlpha || showBeta || showGamma }"></section>
# </nav-dropdown>
# <div class="stats-splits" data-ng-cloak="" data-ng-controller="PlayersLeadersAlltimeController">
# <div class="row row5 collapse stats-filters-top">
# <div class="columns large-1"><div autorun="true" split="splits.SeasonType" stats-filter-select=""></div></div>
# <div class="columns large-1"><div autorun="true" split="splits.PerMode" stats-filter-select=""></div></div>
# <div class="columns large-1"><div autorun="true" split="splits.StatCategory" stats-filter-select=""></div></div>
# <div class="columns large-1"><div autorun="true" split="splits.ActiveFlag" stats-filter-toggle=""></div></div>
# <div class="columns large-1 end"><button class="stats-filters-advanced__toggle" ng-click="showSplits=!showSplits">Advanced Filters</button></div>
# </div>
# <div class="stats-filters-advanced" ng-show="showSplits">
# <div class="row row5 collapse">
# <div class="columns medium-1 end">
# <div class="stats-filters-advanced__category">Custom Filters</div>
# <div fields="customFields" filters="filters" stats-custom-filters=""></div>
# </div>
# </div>
# <div class="stats-filters-advanced__bottom">
# <stats-filter-reset></stats-filter-reset>
# <stats-run-it></stats-run-it>
# </div>
# </div>
# <div class="row stats-pill-section nba-m-t-1 nba-m-b-1">
# <div class="columns medium-6">
# <stats-filter-pills></stats-filter-pills>
# </div>
# <div class="columns medium-6 text-right">
# <stats-recent-filters></stats-recent-filters>
# <stats-glossary-toggle toggle="showGlossary"></stats-glossary-toggle>
# <stats-share-button data-title="{{ pageTitle }}"></stats-share-button>
# </div>
# </div> <!-- .stats-pill-section -->
# <div class="stats-glossary" ng-show="showGlossary">
# <dl>
# <dt>GP</dt>
# <dd>Games Played</dd>
# <dt>MIN</dt>
# <dd>Minutes Played</dd>
# <dt>PTS</dt>
# <dd>Points</dd>
# <dt>FGM</dt>
# <dd>Field Goals Made</dd>
# <dt>FGA</dt>
# <dd>Field Goals Attempted</dd>
# <dt>FG%</dt>
# <dd>Field Goal Percentage</dd>
# <dt>3PM</dt>
# <dd>3 Point Field Goals Made</dd>
# <dt>3PA</dt>
# <dd>3 Point Field Goals Attempted</dd>
# <dt>3P%</dt>
# <dd>3 Point Field Goals Percentage</dd>
# <dt>FTM</dt>
# <dd>Free Throws Made</dd>
# <dt>FTA</dt>
# <dd>Free Throws Attempted</dd>
# <dt>FT%</dt>
# <dd>Free Throw Percentage</dd>
# <dt>OREB</dt>
# <dd>Offensive Rebounds</dd>
# <dt>DREB</dt>
# <dd>Defensive Rebounds</dd>
# <dt>REB</dt>
# <dd>Rebounds</dd>
# <dt>AST</dt>
# <dd>Assists</dd>
# <dt>STL</dt>
# <dd>Steals</dd>
# <dt>BLK</dt>
# <dd>Blocks</dd>
# <dt>TOV</dt>
# <dd>Turnovers</dd>
# <dt>eFG%</dt>
# <dd>Effective Field Goal Percentage</dd>
# <dt>TS%</dt>
# <dd>True Shooting Percentage</dd>
# </dl>
# </div> <!-- .stats-glossary -->
# <div stats-loader="isLoading"></div>
# <div stats-no-data-msg="noData &amp;&amp; !isLoading"></div>
# <nba-stat-table filters="filters" ng-if="!isLoading &amp;&amp; !noData" params="params" rows="playerStats" template="players/players-leaders-alltime"></nba-stat-table>
# </div> <!-- .stats-splits -->
# </div>
# </div>
# </div>
# </div> <!-- .stats-container__inner -->
# </main> <!-- .stats-container -->
# <footer>
# <div id="nba-footer"></div> </footer>
# <script>
#       window.esi_ = {
#         country: "US",
#         tz: "EST",
#         region: "MD",
#         browser: "OTHER",
#         nbarid: "1",
#         nbarn: "United States"
#       };
#     </script>
# <script>
#     window.statsConfig = {
#       statsBuildVersion: "4.47.1",
#       statsBuildType: "prod",
#       statsBuildDate: "2021-12-22T19:51:03.642Z",
#       statsBranch: "release/4.47.1",
#       statsLeagueId: "",
#       statsLeagueName: ""
#     };
#   </script>
# <script async="" src="/include/nav-footer.js"></script>
# <script src="https://www.nba.com/stats/js/data/ptsd/stats_ptsd.js"></script>
# <script src="/stats/scripts/vendor.min.js"></script>
# <script src="/stats/scripts/theme.min.js?rev=5d241bbdd2c3fcf75f49ec1a3598209a"></script>
# <script>
#       function initEndeavor() {
#         if (window && window.NLAAUI) {
#           (new NLAAUI.default()).initialize({ appUrl: 'https://watch.nba.com/' });
#         }
#       }
#     </script>
# <link href="https://neulionms-a.akamaihd.net/qa/nbad/v3/nba/site_4/styles/nlaaui.css" rel="stylesheet"/>
# <script async="" onload="initEndeavor()" src="https://neulionms-a.akamaihd.net/nbad/player/v1/nba/site_4/scripts/nbanlaaeui-prod.min.js"></script>
# <!-- turner ad tag includes -->
# <script src="https://i.cdn.turner.com/ads/adfuel/ais/2.1/nba3-ais.min.js"></script>
# <script src="https://i.cdn.turner.com/ads/adfuel/adfuel-2.1.70.min.js"></script>
# <script type="text/javascript">
#   //Set a listener for GPTRenderComplete Event
#   AdFuel.addEvent(document, 'GPTRenderComplete', function(event) {
#     if (event.detail && !event.detail.isEmpty) {
#       var detail = event.detail;
#       //If ad_bnr_atf_01 is 728x90, dispatch the global marketing slot
#       if (
#         detail.pos[0] === 'bnr_atf_01' &&
#         detail.renderedSize[0] === 728 &&
#         detail.renderedSize[1] === 90
#       ) {
#         AdFuel.queueRegistry(
#           'https://i.cdn.turner.com/ads/nba3/singles/nba_global_mktg.min.js',
#           {
#             dispatch: true,
#           }
#         );
#       }
#     }
#     // Make ad container visible after banner ad loaded
#     const adContainer = document.getElementById('header-ad');
#     if(adContainer && adContainer.classList) {
#       adContainer.classList.add("loaded");
#     }
#   });
#
#   //Dispatch nba_stats registry
#   AdFuel.queueRegistry('https://i.cdn.turner.com/ads/nba3/nba_stats.min.js', {
#     dispatch: true,
#   });
# </script>
# <script type="text/javascript">window.NREUM||(NREUM={});NREUM.info={"beacon":"bam-cell.nr-data.net","licenseKey":"09f0cb5c68","applicationID":"76210961","transactionName":"NgcGZUJQVxYEVEJcCQ9NMUNZHkoRBENFGgcNDhBYXVQUCQBWUlAUEk0NX1RUQUsVX0Y=","queueTime":0,"applicationTime":197,"atts":"GkAFEwpKRBg=","errorBeacon":"bam-cell.nr-data.net","agent":""}</script></body>
# </html>
# >

# %%
# body = soup.find_all('tbody')
# # table = body[0]
# print(body.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-7d013814f456> in <module>
#       1 body = soup.find_all('tbody')
#       2 # table = body[0]
# ----> 3 print(find.body.text)
#
# NameError: name 'find' is not defined

# %%
for i in soup.find_all('tbody'):
    print(i, '\n')
